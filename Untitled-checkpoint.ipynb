# %%
from project import PlotDrawer

drawer = PlotDrawer(r'C:\Users\marge\PycharmProjects\pythonProject1\.ipynb_checkpoints\deviation.json')
columns = ['gt_corners', 'rb_corners', 'mean', 'max', 'min']
plot_paths = drawer.draw_plots(columns)

from IPython.display import Image, display
for plot_path in plot_paths:
    display(Image(filename=plot_path))
